# %%
# pip install openapi dotenv

# %% [markdown]
# OpenAI.API

# %%
from dotenv import load_dotenv
import os

load_dotenv()

# 사용할 키 가져오기
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# %%
from openai import OpenAI

# %%
client = OpenAI(api_key=OPENAI_API_KEY)

# %%
# 응답 생성 : Responses
response = client.responses.create(
    model = 'gpt-5.5',
    input='스타워즈 시리즈의 다스베이더의 역할에 대해 한 줄로 설명해줘'
)

# %%
response
# Out:
# Response(id='resp_06479c1116744dcb006a4e54ddd110819b90d5d26a23699f51', created_at=1783518429.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.5-2026-04-23', object='response', output=[ResponseOutputMessage(id='msg_06479c1116744dcb006a4e54def7a8819b8e53da93275c7eab', content=[ResponseOutputText(annotations=[], text='다스베이더는 스타워즈 시리즈에서 어둠의 세력을 대표하는 시스 군주이자, 루크 스카이워커와 은하계의 운명을 좌우하는 핵심 악역입니다.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase='final_answer')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=0.98, background=False, completed_at=1783518432.0, conversation=None, max_output_tokens=None, max_tool_calls=None, moderation=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention='24h', reasoning=Reasoning(context='current_turn', effort='medium', generate_summary=None, summary=None, mode='standard'), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=27, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=54, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=81), user=None, billing={'payer': 'developer'}, frequency_penalty=0.0, presence_penalty=0.0, store=True, tool_usage={'image_gen': {'input_tokens': 0, 'input_tokens_details': {'image_tokens': 0, 'text_tokens': 0}, 'output_tokens': 0, 'output_tokens_details': {'image_tokens': 0, 'text_tokens': 0}, 'total_tokens': 0}, 'web_search': {'num_requests': 0}})

# %%
print(response.output_text)
# Out:
# 다스베이더는 스타워즈 시리즈에서 어둠의 세력을 대표하는 시스 군주이자, 루크 스카이워커와 은하계의 운명을 좌우하는 핵심 악역입니다.

# %%
response = client.responses.create(
    model = 'gpt-5.5',
    instructions='당신은 영화 평론가야!',
    input='스타워즈 시리즈의 다스베이더의 역할에 대해 설명해줘'
)

print(response.output_text)
# Out:
# 다스 베이더는 **〈스타워즈〉 시리즈의 중심축**이자, 단순한 악당을 넘어 “타락과 구원”이라는 시리즈의 핵심 주제를 대표하는 인물입니다.
#
# ## 1. 제국의 상징이자 공포의 얼굴
#
# 오리지널 3부작에서 다스 베이더는 은하 제국의 집행자입니다. 검은 갑옷, 기계적인 호흡음, 붉은 광선검은 그 자체로 제국의 폭력과 억압을 상징합니다. 그는 황제 팰퍼틴의 오른팔로서 반란군을 추격하고, 제다이의 흔적을 제거하며, 은하계에 공포를 퍼뜨리는 존재입니다.
#
# 특히 베이더는 단순히 “강한 악역”이 아니라, 화면에 등장하는 순간 영화의 공기를 바꾸는 인물입니다. 그의 존재감은 〈스타워즈〉가 우주 모험극이면서도 신화적 비극의 성격을 갖게 만드는 중요한 요소입니다.
#
# ## 2. 루크 스카이워커의 거울
#
# 다스 베이더는 루크 스카이워커의 적이지만, 동시에 루크가 될 수도 있었던 또 다른 가능성입니다. 루크가 분노, 두려움, 복수심에 사로잡힌다면 베이더와 같은 길을 걸을 수 있다는 점에서 그는 주인공의 “어두운 거울” 역할을 합니다.
#
# 이 구조는 〈스타워즈〉의 선과 악을 단순한 대립이 아니라, 한 인간 안에서 벌어지는 내면의 싸움으로 확장시킵니다. 베이더는 루크에게 물리쳐야 할 적이면서도 이해해야 할 존재입니다.
#
# ## 3. 아나킨 스카이워커의 비극
#
# 프리퀄 3부작을 통해 다스 베이더의 정체는 더 깊어집니다. 그는 본래 아나킨 스카이워커라는 뛰어난 제다이였고, 사랑하는 사람을 잃을지 모른다는 두려움과 권력에 대한 유혹 때문에 어둠의 길로 빠집니다.
#
# 이 점에서 베이더는 태어날 때부터 악한 인물이 아니라, 두려움과 집착, 정치적 조작 속에서 무너진 비극적 인물입니다. 프리퀄은 그의 타락을 보여주며, 오리지널 3부작의 베이더를 단순한 악역이 아닌 상처 입은 인간으로 다시 보게 만듭니다.
#
# ## 4. 구원의 서사
#
# 다스 베이더의 가장 중요한 역할은 결국 “구원 가능성”을 보여주는 데 있습니다. 그는 수많은 죄를 저지른 인물이지만, 루크는 그 안에 아직 선함이 남아 있다고 믿습니다. 이 믿음은 시리즈 전체의 도덕적 핵심입니다.
#
# 베이더의 마지막 선택은 〈스타워즈〉가 말하고자 하는 중요한 메시지를 드러냅니다. 인간은 타락할 수 있지만, 마지막 순간까지 선택할 수 있으며, 사랑과 믿음은 어둠을 이길 수 있다는 것입니다.
#
# ## 5. 시리즈 전체의 신화적 중심
#
# 다스 베이더는 〈스타워즈〉의 세계관에서 가장 상징적인 인물입니다. 그는 악역이자 아버지, 제국의 무기이자 몰락한 영웅, 괴물이자 인간입니다. 이런 복합성 때문에 베이더는 영화사에서 가장 유명하고 강력한 캐릭터 중 하나가 되었습니다.
#
# 결국 다스 베이더의 역할은 **악의 화신으로 시작해, 비극적 인간을 거쳐, 구원의 가능성을 증명하는 존재**라고 할 수 있습니다. 〈스타워즈〉는 루크의 성장 이야기이기도 하지만, 더 크게 보면 아나킨 스카이워커가 다스 베이더가 되었다가 다시 인간성을 되찾는 이야기이기도 합니다.

# %%
response = client.responses.create(
    model = 'gpt-5.5', 
    input=[
        {
            'role':'developer',
            'content':'음식에 대한 이야기 하는것을 좋아해'
        },
        {
            'role':'user',
            'content':'오늘 저녁 식사는 무엇을 먹을까?'
        }
    ]
)

print(response.output_text)
# Out:
# 오늘은 기분에 따라 이렇게 골라보면 어때요?
#
# - **든든하게 먹고 싶으면:** 제육볶음 + 쌈채소 + 된장찌개
# - **가볍게 먹고 싶으면:** 샐러드 파스타나 닭가슴살 덮밥
# - **따뜻한 국물이 당기면:** 순두부찌개, 김치찌개, 쌀국수
# - **편하게 배달이면:** 치킨, 마라탕, 초밥, 돈까스
# - **집밥 느낌이면:** 계란말이 + 김치볶음밥 + 미소국
#
# 제 추천은 오늘 저녁엔 **김치찌개에 계란말이**요. 실패하기 어렵고 든든해요.
# 지금 매운 거, 국물, 밥, 면 중에 뭐가 제일 당기세요?

# %% [markdown]
# 유치원 선생님 앱 => 질문을 받아서 답변하는 앱

# %%
user_input = input('안녕하세요! 어린이 여러분!!! 궁금한게 있으면 물어보세요~')
print('질문:', user_input)
# Out:
# 질문: 미니언즈는 어디에 살아요?

# %%
response = client.responses.create(
    model = 'gpt-5.5', 
    input=[
        {
            'role':'developer',
            'content':'너는 유치원 선생님이야. 아이들을 대하는 것처럼 이야기해줘'
        },
        {
            'role':'user',
            'content': user_input
        }
    ]
)

print(response.output_text)
# Out:
# 미니언즈는 **영화 속 친구들**이라서 진짜로 사는 곳은 없어요 😊
#
# 이야기 속에서는 보통 **그루 아저씨의 집**이나 **지하 연구실**에서 같이 지내요.
# 노란 미니언들이 “바나나!” 하면서 우르르 모여 사는 곳이지요 🍌💛

# %% [markdown]
# 2026.07.09

# %%
response = client.chat.completions.create(
    model='gpt-5.5',
    messages = [
        {
            'role' : 'user',
            'content' : '미니언즈 시리즈에 대해 설명해줘'
        }
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# **미니언즈 시리즈**는 일루미네이션 엔터테인먼트가 제작한 애니메이션 프랜차이즈로, 원래는 영화 **〈슈퍼배드〉(Despicable Me)** 시리즈의 조연 캐릭터였던 노란 생명체 **미니언즈**가 큰 인기를 얻으면서 독립 영화까지 만들어진 작품군입니다.
#
# ## 1. 미니언즈는 어떤 캐릭터인가?
# 미니언즈는 작고 노란 몸, 고글, 멜빵바지가 특징인 생명체들입니다.
# 이들은 역사적으로 가장 강력하고 사악한 보스를 섬기려는 본능을 가지고 있으며, 엉뚱하고 사고뭉치 같은 행동으로 웃음을 줍니다.
#
# 대표적인 미니언으로는 다음 캐릭터들이 유명합니다.
#
# - **케빈**: 비교적 리더 역할을 하는 미니언
# - **스튜어트**: 기타를 좋아하고 장난기 많은 미니언
# - **밥**: 순수하고 귀여운 성격의 미니언
#
# 미니언들은 영어, 스페인어, 프랑스어, 이탈리아어 등 여러 언어가 섞인 듯한 독특한 언어인 **미니언어**를 사용합니다.
#
# ## 2. 주요 영화 순서
#
# ### 〈슈퍼배드〉 시리즈
# 미니언즈가 처음 등장한 시리즈입니다.
#
# 1. **슈퍼배드**
#    원제: *Despicable Me*, 2010
#    악당 그루가 세 소녀를 입양하면서 변화하는 이야기를 다룹니다.
#
# 2. **슈퍼배드 2**
#    원제: *Despicable Me 2*, 2013
#    그루가 악당에서 영웅 쪽으로 변화하며 새로운 사건에 휘말립니다.
#
# 3. **슈퍼배드 3**
#    원제: *Despicable Me 3*, 2017
#    그루의 쌍둥이 형제 드루가 등장하고, 새로운 악당과 대결합니다.
#
# 4. **슈퍼배드 4**
#    원제: *Despicable Me 4*, 2024
#    그루 가족과 미니언즈의 새로운 모험을 다룹니다.
#
# ### 〈미니언즈〉 독립 영화
# 미니언즈를 주인공으로 한 스핀오프 작품입니다.
#
# 1. **미니언즈**
#    원제: *Minions*, 2015
#    미니언들이 그루를 만나기 전, 최고의 악당을 찾아다니는 이야기를 그립니다. 스칼렛 오버킬이라는 여성 악당이 주요 인물로 등장합니다.
#
# 2. **미니언즈 2**
#    원제: *Minions: The Rise of Gru*, 2022
#    어린 시절의 그루와 미니언즈가 처음으로 함께하게 되는 과정을 다룹니다.
#
# ## 3. 시리즈의 특징
#
# 미니언즈 시리즈의 가장 큰 특징은 **슬랩스틱 코미디**입니다.
# 복잡한 대사나 설정보다 몸개그, 표정, 소리, 예상치 못한 사고를 통해 웃음을 만듭니다.
#
# 또한 어린이뿐 아니라 성인 관객도 즐길 수 있도록 다음 요소들이 섞여 있습니다.
#
# - 귀여운 캐릭터 디자인
# - 빠른 템포의 코미디
# - 가족애와 우정
# - 악당 캐릭터를 유쾌하게 그리는 설정
# - 유명 팝송과 복고풍 음악 활용
#
# ## 4. 인기 이유
#
# 미니언즈가 전 세계적으로 인기를 얻은 이유는 매우 단순하면서도 강력합니다.
#
# - 언어 장벽이 낮음
# - 외형이 귀엽고 기억하기 쉬움
# - 짧은 장면만 봐도 웃길 수 있음
# - 굿즈, 장난감, 광고 캐릭터로 활용하기 좋음
# - 아이와 어른 모두에게 친근함
#
# 특히 미니언즈는 영화 밖에서도 인형, 문구, 게임, 광고 등 다양한 상품으로 확장되며 하나의 인기 캐릭터 브랜드가 되었습니다.
#
# ## 5. 전체적인 평가
#
# 미니언즈 시리즈는 깊은 서사보다는 **캐릭터의 매력과 코미디**에 초점을 맞춘 애니메이션입니다.
# 스토리는 단순한 편이지만, 미니언들의 엉뚱한 행동과 그루 가족의 따뜻한 이야기가 결합되면서 꾸준히 사랑받고 있습니다.
#
# 간단히 말하면, **미니언즈 시리즈는 귀여운 노란 생명체들이 벌이는 소동을 중심으로 한 유쾌한 가족용 애니메이션 프랜차이즈**라고 할 수 있습니다.

# %% [markdown]
# Function Calling

# %%
import requests

def get_weather(latitude, longitude):
    response = requests.get(f"https://api.open-meteo.com/v1/forecast?latitude={latitude}&longitude={longitude}&current=temperature_2m,wind_speed_10m&hourly=temperature_2m,relative_humidity_2m,wind_speed_10m")
    data = response.json()
    return data['current']['temperature_2m']

# %%
# 함수의 설정(정의)
tools = [
    {
        'type' : 'function',
        'name' : 'get_weather',
        'description' : 'Get current temperature for provided coordinates in celsius.',
        'parameters' : {
            'type' : 'object',
            'properties' : {
                "latitude": {"type": "number"},
                "longitude": {"type": "number"}
            },
        'required' : ["latitude", "longitude"],        
        'additionalProperties' : False
        },
        'strict' : True
    }    
]

# %%
input_message = [
    {
        'role' : 'user',
        'content' : '오늘 파리의 날씨는 어때?'
    }
]

response = client.responses.create(
    model='gpt-5.5',
    input = input_message,
    tools = tools
)

# %%
dict(response.output[1])
# Out:
# {'arguments': '{"latitude":48.8566,"longitude":2.3522}',
#  'call_id': 'call_ujSqZBEh667C9fxSHcxBoCiZ',
#  'name': 'get_weather',
#  'type': 'function_call',
#  'id': 'fc_03d331f79c9c4d61006a4f08efff4c819983fa0f4ceffbf765',
#  'namespace': None,
#  'status': 'completed'}

# %%
import json

tool_call = response.output[1]

args = json.loads(tool_call.arguments)
print(args)
# Out:
# {'latitude': 48.8566, 'longitude': 2.3522}

# %%
# 함수 호출
result = get_weather(args['latitude'], args['longitude'])
print('result:', result)
# Out:
# result: 23.6

# %%
# 메시지 병합
input_message.append(tool_call)

# 함수 실행 결과도 병합
input_message.append(
    {
        'type' : 'function_call_output',
        'call_id' : tool_call.call_id,
        'output' : str(result)
    }
)

print(input_message)
# Out:
# [{'role': 'user', 'content': '오늘 파리의 날씨는 어때?'}, ResponseFunctionToolCall(arguments='{"latitude":48.8566,"longitude":2.3522}', call_id='call_ujSqZBEh667C9fxSHcxBoCiZ', name='get_weather', type='function_call', id='fc_03d331f79c9c4d61006a4f08efff4c819983fa0f4ceffbf765', namespace=None, status='completed'), {'type': 'function_call_output', 'call_id': 'call_ujSqZBEh667C9fxSHcxBoCiZ', 'output': '23.6'}, ResponseFunctionToolCall(arguments='{"latitude":48.8566,"longitude":2.3522}', call_id='call_ujSqZBEh667C9fxSHcxBoCiZ', name='get_weather', type='function_call', id='fc_03d331f79c9c4d61006a4f08efff4c819983fa0f4ceffbf765', namespace=None, status='completed'), {'type': 'function_call_output', 'call_id': 'call_ujSqZBEh667C9fxSHcxBoCiZ', 'output': '23.6'}]

# %%
response2 = client.responses.create(
    model = 'gpt-5.5',
    input = input_message,
    tools = tools
)
